# %% [markdown]
# # **Milestone 1 - Basics**

# %% [markdown]
# This section contains tasks that will help you get familiar with the basics of image processing.
#
# You may add more code and markdown cells as needed

# %% [markdown]
# ## TASK 1
# * Load a 512x512 image
# * Initialize with random rgb values
# * Display it

# %% [markdown]
# #### Importing the libraries

# %%
## Hint:load opencv and numpy

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Define the variables to store a 3d matrix for the image

# %%
## Hint: use numpy
height = 512
width = 512
color_channels = 3

# %% [markdown]
# #### Initialize the matrix with random rgb values

# %%
## Hint: use random package

image_matrix = np.random.randint(0, 256, (height, width, color_channels), dtype=np.uint8)

# %% [markdown]
# #### Display the random image

# %%
## Hint: use matplotlib

plt.imshow(image_matrix)
#plt.axis('off')  
plt.show()

# %% [markdown]
# ## TASK 2
#
# * Load a 512x512 image
# * Initialize with random rgb values
# * Tranform the image into a grayscale image
# * Display it

# %% [markdown]
# #### Convert `TASK 1` Image to corresponding grayscale image
# (without using any inbuilt function of `opencv`)

# %%
## Hint: use the variable from TASK 1

height = 512
width = 512
color_channels = 3

# %% [markdown]
# #### Display the grayscale image

# %%
gray_image = 0.2989 * image_matrix[:, :, 0] + 0.5870 * image_matrix[:, :, 1] + 0.1140 * image_matrix[:, :, 2]
gray_image = gray_image.astype(np.uint8)  

plt.imshow(gray_image, cmap='gray') 
plt.axis('off')  
plt.show()

# %% [markdown]
# ## TASK 3
# * Load the Fingerprint Image `datasets\task3\1.tiff`
# * Display it
# * Load the Fingerprint Image `datasets\task3\2.tiff`
# * Display it

# %% [markdown]
# #### Load the Fingerprint Image `datasets\task3\1.tiff`

# %%
## Hint: use opencv

first_fingerprint = cv2.imread('datasets\\task3\\1.tiff', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# #### Display the First Fingerprint image

# %%
## Hint: use matplotlib
plt.imshow(first_fingerprint, cmap='gray')
plt.title('First Fingerprint Image')
plt.axis('off')  # Hide the axis
plt.show()

# %% [markdown]
# #### Load the Fingerprint Image `datasets\task3\2.tiff`

# %%
## Hint: use opencv

second_fingerprint = cv2.imread('datasets\\task3\\2.tiff', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# #### Display the Second Fingerprint image

# %%
## Hint: use matplotlib
plt.imshow(second_fingerprint, cmap='gray')
plt.title('Second Fingerprint Image')
plt.axis('off')  # Hide the axis
plt.show()
